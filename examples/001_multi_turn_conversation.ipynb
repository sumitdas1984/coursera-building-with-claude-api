# %%
# # Install dependencies
# %pip install anthropic python-dotenv

# %%
# Load env variables
from dotenv import load_dotenv
import os

load_dotenv
# Out:
# <function dotenv.main.load_dotenv(dotenv_path: Union[str, ForwardRef('os.PathLike[str]'), NoneType] = None, stream: Optional[IO[str]] = None, verbose: bool = False, override: bool = False, interpolate: bool = True, encoding: Optional[str] = 'utf-8') -> bool>

# %%
# Create an API client instance
from anthropic import Anthropic

client = Anthropic()

# %%
def add_user_message(messages, text):
    messages.append({"role": "user", "content": text})


def add_assistant_message(messages, text):
    messages.append({"role": "assistant", "content": text})     
    

def chat(messages):
    message = client.messages.create(
        model="claude-3-5-haiku-20241022",
        max_tokens=1000,
        messages=messages
    )
    return message.content[0].text

# %%
# Make a starting list of messages
messages = []
# messages

# Add in the initial user question of "What is deep learning?"
add_user_message(messages, "What is deep learning?")
# messages

# Pass the list of messages into 'chat' to get an answer
answer = chat(messages)
# answer

# Take the answer and add it as an assistant message to the list of messages
add_assistant_message(messages, answer)
# messages

# Add in the user's follow-up question
add_user_message(messages, "What are some applications of it?")
# messages

# Call chat again with the updated list of messages to get a final answer
final_answer = chat(messages)
final_answer
# Out:
# 'Deep learning is a subset of machine learning that uses artificial neural networks with multiple layers (hence "deep") to progressively extract higher-level features from raw input. Here\'s a detailed overview:\n\nCore Characteristics:\n- Uses multiple-layer neural networks\n- Can automatically learn features from raw data\n- Mimics the way human brain processes information\n- Requires large amounts of data\n- Uses complex mathematical models\n\nKey Applications:\n\n1. Computer Vision\n- Image recognition\n- Facial recognition\n- Autonomous vehicle perception\n- Medical image analysis\n- Object detection\n\n2. Natural Language Processing\n- Language translation\n- Speech recognition\n- Chatbots\n- Text generation\n- Sentiment analysis\n\n3. Healthcare\n- Disease diagnosis\n- Medical image interpretation\n- Drug discovery\n- Predicting patient outcomes\n\n4. Finance\n- Fraud detection\n- Stock market prediction\n- Credit scoring\n- Algorithmic trading\n\n5. Robotics\n- Motion plannin
# ...
