# %%
# Load env variables
from dotenv import load_dotenv
import os

load_dotenv
# Out:
# <function dotenv.main.load_dotenv(dotenv_path: Union[str, ForwardRef('os.PathLike[str]'), NoneType] = None, stream: Optional[IO[str]] = None, verbose: bool = False, override: bool = False, interpolate: bool = True, encoding: Optional[str] = 'utf-8') -> bool>

# %%
# Create an API client instance
from anthropic import Anthropic

client = Anthropic()

# %%
def add_user_message(messages, text):
    messages.append({"role": "user", "content": text})


def add_assistant_message(messages, text):
    messages.append({"role": "assistant", "content": text})     
    

def chat(messages, system=None):
    params = {
        "model":"claude-3-5-haiku-20241022",
        "max_tokens":1000,
        "messages":messages,
    }

    if system:
        params["system"] = system
        
    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Make an initial list of messages
messages = []

system = """
You are a patient math tutor.
Do not directly anaser a student's question.
Guide them to a solution step by step.
"""

add_user_message(messages, "How do I solve 5x+3=2 for x?")
answer = chat(messages, system)

answer
# Out:
# "Let's solve this step by step:\n\n1. First, your goal is to isolate x on one side of the equation.\n\n2. Right now, you have 5x+3=2\n\n3. To get x by itself, first subtract 3 from both sides of the equation:\n   • 5x+3-3 = 2-3\n   • 5x = -1\n\n4. Now, to get x alone, divide both sides by 5:\n   • 5x ÷ 5 = -1 ÷ 5\n   • x = -1/5 or -0.2\n\n5. Let's check our work:\n   • Plug -1/5 back into the original equation\n   • 5(-1/5) + 3 = 2\n   • -1 + 3 = 2\n   • 2 = 2 ✓\n\nWould you like to try solving this on your own first, or would you like me to explain any of these steps in more detail?"
