# %%
# Load env variables
from dotenv import load_dotenv
import os

load_dotenv
# Out:
# <function dotenv.main.load_dotenv(dotenv_path: str | ForwardRef('os.PathLike[str]') | None = None, stream: IO[str] | None = None, verbose: bool = False, override: bool = False, interpolate: bool = True, encoding: str | None = 'utf-8') -> bool>

# %%
# Create an API client instance
from anthropic import Anthropic

client = Anthropic()

# %%
def add_user_message(messages, text):
    messages.append({"role": "user", "content": text})


def add_assistant_message(messages, text):
    messages.append({"role": "assistant", "content": text})     
    

def chat(messages, system=None):
    params = {
        "model":"claude-3-5-haiku-20241022",
        "max_tokens":1000,
        "messages":messages,
    }

    if system:
        params["system"] = system
        
    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Make an initial list of messages
messages = []

# system = """
# You are a python engineer who writes very concise and readable code.
# """

add_user_message(messages, "Write a 8 line poem about the beauty of nature.")

with client.messages.stream(
    model="claude-3-5-haiku-20241022",
    max_tokens=1000,
    messages=messages,
) as stream:
    for text in stream.text_stream:
        # print(text, end="")
        pass

full_text = stream.get_final_message().content[0].text
full_text
# Out:
# "Here's an 8-line poem about the beauty of nature:\n\nVerdant hills and crystal streams,\nWhere sunlight dances and nature gleams,\nSoft petals swaying in gentle breeze,\nMajestic mountains and whispering trees.\n\nStarlit skies of deepest blue,\nLandscapes painted in vibrant hue,\nDelicate flowers and rolling plains,\nEarth's beauty that forever remains."
