# %%
# Load env variables
from dotenv import load_dotenv
import os

load_dotenv
# Out:
# <function dotenv.main.load_dotenv(dotenv_path: Union[str, ForwardRef('os.PathLike[str]'), NoneType] = None, stream: Optional[IO[str]] = None, verbose: bool = False, override: bool = False, interpolate: bool = True, encoding: Optional[str] = 'utf-8') -> bool>

# %%
# Create an API client instance
from anthropic import Anthropic

client = Anthropic()

# %%
def add_user_message(messages, text):
    messages.append({"role": "user", "content": text})


def add_assistant_message(messages, text):
    messages.append({"role": "assistant", "content": text})     
    

def chat(messages, system=None):
    params = {
        "model":"claude-3-5-haiku-20241022",
        "max_tokens":1000,
        "messages":messages,
    }

    if system:
        params["system"] = system
        
    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Make an initial list of messages
messages = []

system = """
You are a python engineer who writes very concise and readable code.
"""

add_user_message(messages, "Write a python function that checks a string for duplicate characters.")
answer = chat(messages, system)

answer
# Out:
# 'Here are a few different approaches to solve this problem, from simple to more advanced:\n\n```python\n# Solution 1: Using set() - most concise\ndef has_duplicates(s):\n    return len(s) != len(set(s))\n\n# Solution 2: Using collections Counter\ndef has_duplicates_counter(s):\n    from collections import Counter\n    return any(count > 1 for count in Counter(s).values())\n\n# Solution 3: Using dictionary comprehension \ndef has_duplicates_dict(s):\n    return len({char: s.count(char) for char in set(s) if s.count(char) > 1}) > 0\n\n# Solution 4: Most explicit approach with basic loop\ndef has_duplicates_loop(s):\n    seen = set()\n    for char in s:\n        if char in seen:\n            return True\n        seen.add(char)\n    return False\n\n# Example usage\nprint(has_duplicates("hello"))  # True\nprint(has_duplicates("python"))  # False\n```\n\nEach solution has its pros and cons:\n- Solution 1 is the most concise\n- Solution 2 uses Counter for more complex frequency tracking\n- Solution 3 is a one-liner with dictionary comprehension\n- Solution 4 is the most traditional and explicit approach\n\nChoose based on readability and specific use case.'
