# %%
# # Install dependencies
# %pip install anthropic python-dotenv

# %%
# Load env variables
from dotenv import load_dotenv
import os

load_dotenv
# Out:
# <function dotenv.main.load_dotenv(dotenv_path: Union[str, ForwardRef('os.PathLike[str]'), NoneType] = None, stream: Optional[IO[str]] = None, verbose: bool = False, override: bool = False, interpolate: bool = True, encoding: Optional[str] = 'utf-8') -> bool>

# %%
# Create an API client instance
from anthropic import Anthropic

client = Anthropic()

# %%
# Make a request to the API
message = client.messages.create(
    model="claude-3-5-haiku-20241022",
    max_tokens=1000,
    messages=[
        {
            "role": "user", 
            "content": "What is deep learning? Answer in one sentence"
        }
    ]
)

# %%
message.content[0].text
# Out:
# 'Deep learning is a subset of machine learning that uses artificial neural networks with multiple layers to progressively extract higher-level features from raw input, enabling advanced pattern recognition and decision-making in complex tasks like image recognition, natural language processing, and speech recognition.'
